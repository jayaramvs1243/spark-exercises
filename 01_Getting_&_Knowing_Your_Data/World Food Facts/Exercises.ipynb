# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %%
FILE_PATH = '/Users/jai/Downloads/en.openfoodfacts.org.products.tsv'

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
from pyspark.sql import SparkSession

spark_context = SparkSession.builder.appName('Spark Exercises').getOrCreate()

df_food \
    = spark_context \
        .read \
        .csv(path=FILE_PATH, sep='\t', header=True, inferSchema=True)
df_food.show(5)
# Out:
# +-------+--------------------+--------------------+----------+--------------------+---------------+----------------------+--------------------+------------+--------+---------+--------------+---------------+---------------+----------+---------------+-------------+-------+------------+--------------------+-------------------------+------+-----------+---------+---------+--------------+------------------------+------+-----------+---------------+------+---------+----------------+-------------+--------------------+---------+------------+------+-----------+---------+---------------+-------------+-----------+--------------------+--------------+------------+---------------------------+-------------------------+------------------------------+---------------------------------------+-------------------------------------+------------------------------------------+------------------+------------------+-------------+-------------+--------------------+--------------------+--------------------+------
# ...

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
df_food.limit(5).show()
# Out:
# +-------+--------------------+--------------------+----------+--------------------+---------------+----------------------+--------------------+------------+--------+---------+--------------+---------------+---------------+----------+---------------+-------------+-------+------------+--------------------+-------------------------+------+-----------+---------+---------+--------------+------------------------+------+-----------+---------------+------+---------+----------------+-------------+--------------------+---------+------------+------+-----------+---------+---------------+-------------+-----------+--------------------+--------------+------------+---------------------------+-------------------------+------------------------------+---------------------------------------+-------------------------------------+------------------------------------------+------------------+------------------+-------------+-------------+--------------------+--------------------+--------------------+------
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
from pyspark.sql import functions as F

df_food.select(F.count('*').alias('number_of_observations')).show()
# Out:
# +----------------------+
# |number_of_observations|
# +----------------------+
# |                356027|
# +----------------------+

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(df_food.columns)
# Out:
# 163

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df_food.columns
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
COLUMN_INDEX = 105
df_food.columns[COLUMN_INDEX - 1]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
df_food.select(df_food.columns[COLUMN_INDEX - 1]).dtypes
# Out:
# [('-glucose_100g', 'double')]

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
df_food = df_food.withColumn('product_index', F.monotonically_increasing_id())
df_food.show(10)
# Out:
# +-------+--------------------+--------------------+----------+--------------------+---------------+----------------------+--------------------+------------+--------+---------+--------------+--------------------+--------------------+----------+---------------+-------------+-------+------------+--------------------+-------------------------+------+-----------+---------+---------+--------------+------------------------+------+-----------+---------------+------+---------+----------------+-------------+--------------------+---------+------------+------+-----------+---------+---------------+-------------+-----------+--------------------+--------------+------------------+---------------------------+-------------------------+------------------------------+---------------------------------------+-------------------------------------+------------------------------------------+------------------+------------------+-------------+-------------+--------------------+--------------------+-----------
# ...

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
COLUMN_INDEX = 19

df_food \
    .filter((df_food.product_index == (COLUMN_INDEX - 1))) \
    .select(df_food.product_name) \
    .show()

df_food \
    .offset(COLUMN_INDEX - 1) \
    .limit(1) \
    .select(df_food.product_name) \
    .show()
# Out:
# +--------------------+
# |        product_name|
# +--------------------+
# |Lotus Organic Bro...|
# +--------------------+
# [Stage 41:=======>                                                  (1 + 7) / 8]
# +--------------------+
# |        product_name|
# +--------------------+
# |Lotus Organic Bro...|
# +--------------------+
